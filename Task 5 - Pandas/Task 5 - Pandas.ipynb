# %% [markdown]
# ## TASK 5
#
# ### NAME : AVINASH M
# ### REG NO. : GO_STP_8305
# ### DATE : 28.05.2021

# %% [markdown]
# ___

# %% [markdown]
# ### ***Pandas - Data Analysis of IMDB movies data 2006 - 2016***

# %% [markdown]
# ___

# %% [markdown]
# **Importing numpy and pandas libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ___

# %% [markdown]
# **Load the IMDb Dataset and read**

# %%
df = pd.read_csv("IMDB-Movie-Data.csv")

# %% [markdown]
# ___

# %% [markdown]
# **View the dataset**

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %% [markdown]
# ___

# %% [markdown]
# **Understand some basic information about the dataset and Inspect the dataframe Inspect the dataframe's columns, shapes, variable types etc.**

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
df.size
# Out:
# 12000

# %%
df.empty
# Out:
# False

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#         'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#         'Metascore'],
#        dtype='object')]

# %% [markdown]
# ___

# %% [markdown]
# **Data Selection – Indexing and Slicing data**

# %%
# Indexing
df[["Rank", "Director"]]
# Out:
#      Rank              Director
# 0       1            James Gunn
# 1       2          Ridley Scott
# 2       3    M. Night Shyamalan
# 3       4  Christophe Lourdelet
# 4       5            David Ayer
# ..    ...                   ...
# 995   996             Billy Ray
# 996   997              Eli Roth
# 997   998            Jon M. Chu
# 998   999        Scot Armstrong
# 999  1000      Barry Sonnenfeld
#
# [1000 rows x 2 columns]

# %%
# Slicing
print("Top 10 Movies and it's directors")
df.loc[:10, ["Title", "Director"]]
# Out:
# Top 10 Movies and it's directors
#                                       Title              Director
# 0                   Guardians of the Galaxy            James Gunn
# 1                                Prometheus          Ridley Scott
# 2                                     Split    M. Night Shyamalan
# 3                                      Sing  Christophe Lourdelet
# 4                             Suicide Squad            David Ayer
# 5                            The Great Wall           Yimou Zhang
# 6                                La La Land       Damien Chazelle
# 7                                  Mindhorn            Sean Foley
# 8                        The Lost City of Z            James Gray
# 9                                Passengers         Morten Tyldum
# 10  Fantastic Beasts and Where to Find Them           David Yates

# %%
df.iloc[-10:, 8]
# Out:
# 990    6.6
# 991    8.5
# 992    6.3
# 993    5.9
# 994    6.7
# 995    6.2
# 996    5.5
# 997    6.2
# 998    5.6
# 999    5.3
# Name: Rating, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# **Data Selection – Based on Conditional filtering**

# %%
print("Movies with 8.5+ Rating")
moviesWith8point5PlusRating = df.loc[(df["Rating"] > 8.5), ["Title", "Director", "Rating", "Year"]]
moviesWith8point5PlusRating
# Out:
# Movies with 8.5+ Rating
#                 Title           Director  Rating  Year
# 36       Interstellar  Christopher Nolan     8.6  2014
# 54    The Dark Knight  Christopher Nolan     9.0  2008
# 80          Inception  Christopher Nolan     8.8  2010
# 96      Kimi no na wa     Makoto Shinkai     8.6  2016
# 117            Dangal      Nitesh Tiwari     8.8  2016
# 249  The Intouchables    Olivier Nakache     8.6  2011

# %%
print("Movies with 8.5+ Rating directed by Christopher Nolan")
moviesWith8point5PlusRating.loc[(moviesWith8point5PlusRating["Director"] == "Christopher Nolan"), ["Title", "Rating"]]
# Out:
# Movies with 8.5+ Rating directed by Christopher Nolan
#               Title  Rating
# 36     Interstellar     8.6
# 54  The Dark Knight     9.0
# 80        Inception     8.8

# %%
print("Movies released in 2011 with a rating of 8+")
df[(df["Year"] == 2011) & (df["Rating"] > 8)]
# Out:
# Movies released in 2011 with a rating of 8+
#      Rank                                         Title  \
# 92     93                                      The Help
# 114   115  Harry Potter and the Deathly Hallows: Part 2
# 194   195                                       Warrior
# 249   250                              The Intouchables
#
#                        Genre  \
# 92                     Drama
# 114  Adventure,Drama,Fantasy
# 194       Action,Drama,Sport
# 249   Biography,Comedy,Drama
#
#                                            Description         Director  \
# 92   An aspiring author during the civil rights mov...      Tate Taylor
# 114  Harry, Ron and Hermione search for Voldemort's...      David Yates
# 194  The youngest son of an alcoholic former boxer ...   Gavin O'Connor
# 249  After he becomes a quadriplegic from a paragli...  Olivier Nakache
#
#                                                 Actors  Year  \
# ...

# %% [markdown]
# ___

# %% [markdown]
# **Groupby operations**

# %%
df.groupby("Director")["Rating"].mean()
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
#                        ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 644, dtype: float64

# %%
print("Number of movies released in each year")
df.groupby("Year")["Year"].count()
# Out:
# Number of movies released in each year
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# Name: Year, dtype: int64

# %% [markdown]
# ___

# %% [markdown]
# **Sorting operation**

# %%
print("Number of movies in each year without Sorting")
df.groupby("Year", sort = False)["Year"].count()
# Out:
# Number of movies in each year without Sorting
# Year
# 2014     98
# 2012     64
# 2016    297
# 2015    127
# 2007     53
# 2011     63
# 2008     52
# 2006     44
# 2009     51
# 2010     60
# 2013     91
# Name: Year, dtype: int64

# %%
print("Movies with 8.5+ Rating sorted by Year of release")
moviesWith8point5PlusRating.sort_values("Year")
# Out:
# Movies with 8.5+ Rating sorted by Year of release
#                 Title           Director  Rating  Year
# 54    The Dark Knight  Christopher Nolan     9.0  2008
# 80          Inception  Christopher Nolan     8.8  2010
# 249  The Intouchables    Olivier Nakache     8.6  2011
# 36       Interstellar  Christopher Nolan     8.6  2014
# 96      Kimi no na wa     Makoto Shinkai     8.6  2016
# 117            Dangal      Nitesh Tiwari     8.8  2016

# %% [markdown]
# ___

# %% [markdown]
# **Dealing with missing values**

# %%
df.isna().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# ___

# %% [markdown]
# **Dropping columns and null values**

# %%
# drop column
df.drop("Description", axis = 1)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                  Director                                             Actors  \
# 0              James Gunn  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# ...

# %%
#drop null values
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Rank                  838
# Title                 838
# Genre                 838
# Description           838
# Director              838
# Actors                838
# Year                  838
# Runtime (Minutes)     838
# Rating                838
# Votes                 838
# Revenue (Millions)    838
# Metascore             838
# dtype: int64

# %% [markdown]
# ___

# %% [markdown]
# **Apply functions**

# %%
df.groupby("Director")[["Rating", "Metascore"]].agg([np.mean, np.median, np.sum])
# Out:
#                     Rating              Metascore
#                       mean median   sum      mean median    sum
# Director
# Aamir Khan            8.50    8.5   8.5      42.0   42.0   42.0
# Abdellatif Kechiche   7.80    7.8   7.8      88.0   88.0   88.0
# Adam McKay            7.00    6.8  28.0      65.5   65.0  262.0
# Adam Shankman         6.30    6.3  12.6      64.0   64.0  128.0
# Adam Wingard          5.90    5.9  11.8      61.5   61.5  123.0
# ...                    ...    ...   ...       ...    ...    ...
# Xavier Dolan          8.10    8.1   8.1      74.0   74.0   74.0
# Yimou Zhang           6.10    6.1   6.1      42.0   42.0   42.0
# Yorgos Lanthimos      7.20    7.2  14.4      77.5   77.5  155.0
# Zack Snyder           7.04    7.1  35.2      48.0   52.0  240.0
# Zackary Adler         5.10    5.1   5.1      90.0   90.0   90.0
#
# [524 rows x 6 columns]

# %%
df.mean()
# Out:
# Rank                     485.247017
# Year                    2012.507160
# Runtime (Minutes)        114.638425
# Rating                     6.814320
# Votes                 193230.251790
# Revenue (Millions)        84.564558
# Metascore                 59.575179
# dtype: float64

# %%
df.sort_index(axis = 1)
# Out:
#                                                 Actors  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...
# ..                                                 ...
# 993  Milla Jovovich, Ali Larter, Wentworth Miller,K...
# 994  Thomas Mann, Oliver Cooper, Jonathan Daniel Br...
# 996  Lauren German, Heather Matarazzo, Bijou Philli...
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.sort_values("Votes")
# Out:
#      Rank                  Title                    Genre  \
# 250   251           Bonjour Anne     Comedy,Drama,Romance
# 616   617   2307: Winter's Dream                   Sci-Fi
# 44     45              Lowriders                    Drama
# 68     69              Wakefield                    Drama
# 548   549                  Chuck    Biography,Drama,Sport
# ..    ...                    ...                      ...
# 76     77           The Avengers            Action,Sci-Fi
# 36     37           Interstellar   Adventure,Drama,Sci-Fi
# 124   125  The Dark Knight Rises          Action,Thriller
# 80     81              Inception  Action,Adventure,Sci-Fi
# 54     55        The Dark Knight       Action,Crime,Drama
#
#                                            Description              Director  \
# 250  Anne is at a crossroads in her life. Long marr...       Eleanor Coppola
# 616  In 2307, a future soldier is sent on a mission...           Joey Curtis
# ...

# %% [markdown]
# ___
